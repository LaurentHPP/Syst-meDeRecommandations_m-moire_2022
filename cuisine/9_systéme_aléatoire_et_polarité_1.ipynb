# %%
import pandas as pd
import random,re

# %%
df = pd.read_csv("cusine_nom_2_URL.csv")
list_cusine = []

for i in df["Nom de cusine"] :
    list_cusine.append(i)

# %%
import json

f= open("cusine_URL_Nom_WIKI.json", encoding = "utf-8")

dic = json.load(f)

f.close()

# %%
dic_inverse = {}
for c, v in dic.items():

    valeur = c[1:-1]
    cle = v[0].replace(" ","_")
    dic_inverse[cle]=valeur

# %%
print(dic_inverse['Baked_Alaska'])
# Out:
# http://www.wikidata.org/entity/Q540289

# %%
# la fonction qui nous permet de générer la recommandation aléatoire

def recommander(pos,neg):
    liste = random.sample(list_cusine,5)
 
    print("Je vous conseille de manger les cusines suivantes :")
    print("\n")
    print("="*50)
    print("\n")
    #RegexTxt = re.compile(r'Q[0-9]+')
    for i in range(len(liste)):
      
        print("Numéro",i+1,":",liste[i][1:-1])
        s = str(liste[i][2:-2]).replace(" ","_")
  
        print("Pour plus de l'information, cliquez : ", dic_inverse[s])
        print("\n")

# %%
recommander(["baozi","matzah_pizza"],["doner_kebab"])
# Out:
# Je vous conseille de manger les cusines suivantes :
#
#
# ==================================================
#
#
# Numéro 1 : 'kleicha'
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q6420111
#
#
# Numéro 2 : 'Malakoff'
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q1886687
#
#
# Numéro 3 : 'turnover'
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q10785085
#
#
# Numéro 4 : 'Mućkalica'
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q6944521
#
#
# Numéro 5 : 'kalakukko'
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q612661

# %%
def dico_wikidata_ranks(chemin="./2021-11-15.allwiki.links.rank") :
    dico_ranks = {}
    cpt = 0
    with open(chemin,"r",encoding="utf-8") as f :
        ligne = f.readline()
        ligne = ligne[:len(ligne)-1]

        while ligne :
            cpt+=1
            liste = ligne.split("\t")
            dico_ranks[liste[0]] = float(liste[1])

            ligne = f.readline()
            ligne = ligne[:len(ligne)-1]

    return dico_ranks
dico_ranks = dico_wikidata_ranks(chemin="../PageRank/2021-11-15.allwiki.links.rank")

# %%
liste_label = []
liste_URL = []
liste_entite = []
for c, v in dic.items():
    liste_URL.append(c)
    liste_entite.append(v[0])

# %%
RegexTxt = re.compile(r'Q[0-9]+')
for i in liste_URL:
    liste_label.append(RegexTxt.search(i).group())

# %%
dic_nom_label = dict(zip(liste_entite,liste_label))
dic_label_nom = dict(zip(liste_label,liste_entite))

# %%
print(dic_nom_label)
# Out:
# {'Q589264': 'Q589264', 'Cajun cuisine': 'Q969579', 'Dutch-Antillian cuisine': 'Q2053168', 'Indonesian-Dutch cuisine': 'Q2228549', 'Q3006899': 'Q3006899', 'Q3699117': 'Q3699117', 'Q3699150': 'Q3699150', 'Chettinad cuisine': 'Q3525354', 'Bouchon': 'Q3006973', 'tea culture': 'Q4348225', 'Ancient Egyptian cuisine': 'Q432535', 'vegetarian cuisine': 'Q638022', 'Levantine cuisine': 'Q765174', 'seafood': 'Q192935', 'Aztec cuisine': 'Q2006309', 'Creole cuisine': 'Q85430164', 'Roman cuisine': 'Q3
phòng cuisine': 'Q10842975', 'Q99522230': 'Q99522230', 'Cuisine of Hidalgo': 'Q28662742', 'lashka': 'Q65737686', 'Ashkenazi Jewish cuisine': 'Q84184760', 'broth': 'Q275068', 'mashed potato': 'Q322787', 'soft drink': 'Q147538', 'dessert': 'Q182940', 'stinky tofu': 'Q701628', 'donburi': 'Q1061842', 'Ensaïmada': 'Q1344218', 'Q1857976': 'Q1857976', 'Q1860324': 'Q1860324', 'Q1867162': 'Q1867162', 'Q2007824': 'Q2007824', 'Q2089470': 'Q2089470', 'Q2144948': 'Q2144948', 'Q2170924': 'Q2170924', 'Q2194275': 'Q2194275', 'Q2194659': 'Q2194659', 'Japanese rice dish': 'Q1683302', 'meat dish': 'Q1427844', 'Q2609925': 'Q2609925', 'Q2629070': 'Q2629070', 'Q2691193': 'Q2691193', 'tataki': 'Q2421293', 'taco': 'Q191655', 'Q3676249': 'Q3676249', 'Hallaca': 'Q3085085', 'dip': 'Q2046560', 'Q5701588': 'Q5701588', 'chicken rice': 'Q5363430', 'Q6501674': 'Q6501674', 'li hing mui': 'Q6539361', 'fast food': 'Q81799', 'Pizza bagel': 'Q7199982', 'Butterbrot': 'Q1018075', 'porridge': 'Q186817', 'potato dish': 'Q10514020', 'shirumono': 'Q9 ...

# %%
dico_ranks_1 = sorted(dico_ranks.items(), key=lambda item:item[1], reverse=True)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
dic_label_PR = {} 

for c,v in dico_ranks.items():
    if c in dic_nom_label.values():
        dic_label_PR[c] = v

# %%
print(dic_nom_label[])
# Out:
# {'Q589264': 'Q589264', 'Cajun cuisine': 'Q969579', 'Dutch-Antillian cuisine': 'Q2053168', 'Indonesian-Dutch cuisine': 'Q2228549', 'Q3006899': 'Q3006899', 'Q3699117': 'Q3699117', 'Q3699150': 'Q3699150', 'Chettinad cuisine': 'Q3525354', 'Bouchon': 'Q3006973', 'tea culture': 'Q4348225', 'Ancient Egyptian cuisine': 'Q432535', 'vegetarian cuisine': 'Q638022', 'Levantine cuisine': 'Q765174', 'seafood': 'Q192935', 'Aztec cuisine': 'Q2006309', 'Creole cuisine': 'Q85430164', 'Roman cuisine': 'Q3699146', 'Q16268311': 'Q16268311', 'Q16481853': 'Q16481853', 'Makki di roti': 'Q5408968', 'Western cuisine': 'Q16143746', 'New Mexican cuisine': 'Q7010123', 'Q18915464': 'Q18915464', 'Saint Louis cuisine': 'Q16984298', 'Christmas Island cuisine': 'Q17002293', 'vegan cuisine': 'Q20669090', 'Nordic cuisine': 'Q20892186', 'Anglo-Indian cuisine': 'Q3595124', 'New American cuisine': 'Q7005323', 'Saint Barthélemy cuisine': 'Q7401021', 'Qiang cuisine': 'Q56301925', 'Sakana': 'Q8011654', 'Q29578381': 'Q29578381', 'Q29639731': 'Q29639731', 'tofu': 'Q177378', 'Jewish cuisine': 'Q284288', 'Samoan cuisine': 'Q101252181', 'Chinese cuisine': 'Q27477
.3860244171811493, 'Q101643769': 0.38588324142888053, 'Q1641858': 0.3842960534539849, 'Q19978986': 0.37745662474895003, 'Q4307698': 0.3718361157955828, 'Q654626': 0.36772660161677173, 'Q106491332': 0.36493294650128666, 'Q1689540': 0.36142257213488876, 'Q332609': 0.3588159131843682, 'Q11937087': 0.3561665270919779, 'Q1886359': 0.3515385035966551, 'Q1753513': 0.347171206220173, 'Q18454935': 0.3410470417702167, 'Q1275345': 0.3394616917011248, 'Q3699150': 0.33638502504282747, 'Q2609925': 0.3352375116845673, 'Q3316163': 0.3324187849380149, 'Q16268311': 0.3311999790421929, 'Q799098': 0.33046567898703383, 'Q3361383': 0.319066735198061, 'Q1954072': 0.3171608110851147, 'Q56392589': 0.31416701598478924, 'Q109038648': 0.3117970491997014, 'Q10373410': 0.3087753263592513, 'Q25468949': 0.30566579950052897, 'Q56296735': 0.3051109240647838, 'Q28668248': 0.3051027966359559, 'Q5862467': 0.29599469253813554, 'Q29578381': 0.29462911446883844, 'Q634703': 0.29340625249432856, 'Q8262017': 0.2915357177929808, 'Q109038040': 0.29134373533204494, 'Q997557': 0.28385863291644386, 'Q5701588': 0.2830659637376591, 'Q109045517': 0.2823694791776217, 'Q109044882': 0.2817474047253626, 'Q12564210': 0.2815023520348737, 'Q2248655': 0.27992420524052775, 'Q109019813': 0.27733121822949364, 'Q10333009': 0.27396384883281766, 'Q2064491': 0.2734078875719599, 'Q18015593': 0.2729320024756166, 'Q1408240': 0.2721983346233759, 'Q20103797': 0.2700922265500242, 'Q545816': 0.26960764102936047, 'Q3589163': 0.26792984680721127, 'Q3676249': 0.2664082670312291, 'Q2178599': 0.2648555933782772, 'Q109041787': 0.26151598594439857, 'Q1571724': 0.26015234307914153, 'Q10392333': 0.25982811133626077, 'Q3897499': 0.2577915940281672, 'Q2849806': 0.25778981159900083, 'Q16735597': 0.25687371187037833, 'Q67577553': 0.2519397901582871, 'Q3294501': 0.25143130039392264, 'Q2144948': 0.25017666691942336, 'Q2551579':  ...

# %%
def recommander(pos,neg):
      
        
    dic_label_PR_1 = sorted(dic_label_PR.items(), key=lambda item:item[1], reverse=True)
    
 
    
        
    print("Je vous conseille de manger les cusines suivantes :")
    print("\n")
    print("="*50)
    print("\n")
    for i in range(5):

        print("Numéro",i+1,":",dic_label_nom[dic_label_PR_1[i][0]])
        print("Pour plus de l'information, cliquez : ", dic_inverse[dic_label_PR_1[i][0]])
        print("\n")

# %%
recommander(["baozi","matzah_pizza"],["doner_kebab"])
# Out:
# Je vous conseille de manger les cusines suivantes :
#
#
# ==================================================
#
#
# Numéro 1 : Q6501674
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q6501674
#
#
# Numéro 2 : Q21045264
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q21045264
#
#
# Numéro 3 : Q5905305
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q5905305
#
#
# Numéro 4 : Q5934858
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q5934858
#
#
# Numéro 5 : Q5700719
# Pour plus de l'information, cliquez :  http://www.wikidata.org/entity/Q5700719
