# %%
# in : query_cusine_wiki.json
# out: NOM_URL.json
#      URL_NOM.json  
#      cusine_avec_chevron.csv   
 

# ce script est pour convertir le fichier json que j'ai téléchargé via wikidata 
# en un dictionnaire dont le key est URL du films et la valeur est son nom.
# en un dictionnaire dont le key est nom du films et la valeur est son URL.
# et en le fichier film_avec_chevron.csv dans lequel les URL des entités ont tous les chevrons.

# %%
import json

# %%
# le fichier query.json est ce que j'ai téléchargé sur Web Wikidata Query Service
chemin = "query.json"

# %%
labels = open(chemin, "r", encoding="UTF-8")

# %%
label_nom = json.load(labels )

# %%
print(len(label_nom))
print(label_nom[:10])
# Out:
# 2795
# [{'item': 'http://www.wikidata.org/entity/Q589264', 'itemLabel': 'Q589264'}, {'item': 'http://www.wikidata.org/entity/Q969579', 'itemLabel': 'Cajun cuisine'}, {'item': 'http://www.wikidata.org/entity/Q2053168', 'itemLabel': 'Dutch-Antillian cuisine'}, {'item': 'http://www.wikidata.org/entity/Q2228549', 'itemLabel': 'Indonesian-Dutch cuisine'}, {'item': 'http://www.wikidata.org/entity/Q3006899', 'itemLabel': 'Q3006899'}, {'item': 'http://www.wikidata.org/entity/Q3699117', 'itemLabel': 'Q3699117'}, {'item': 'http://www.wikidata.org/entity/Q3699150', 'itemLabel': 'Q3699150'}, {'item': 'http://www.wikidata.org/entity/Q3525354', 'itemLabel': 'Chettinad cuisine'}, {'item': 'http://www.wikidata.org/entity/Q3006973', 'itemLabel': 'Bouchon'}, {'item': 'http://www.wikidata.org/entity/Q4348225', 'itemLabel': 'tea culture'}]

# %%
dic_label_nom = {}
for i in label_nom:
    #print(i["item"])
    #print(i["itemLabel"])
    dic_label_nom["<"+i["item"]+">"] = [i["itemLabel"]]

# %%
print(dic_label_nom)
# Out:
# {'<http://www.wikidata.org/entity/Q589264>': ['Q589264'], '<http://www.wikidata.org/entity/Q969579>': ['Cajun cuisine'], '<http://www.wikidata.org/entity/Q2053168>': ['Dutch-Antillian cuisine'], '<http://www.wikidata.org/entity/Q2228549>': ['Indonesian-Dutch cuisine'], '<http://www.wikidata.org/entity/Q3006899>': ['Q3006899'], '<http://www.wikidata.org/entity/Q3699117>': ['Q3699117'], '<http://www.wikidata.org/entity/Q3699150>': ['Q3699150'], '<http://www.wikidata.org/entity/Q3525354>': ['Chettinad cuisine'], '<http://www.wikidata.org/entity/Q3006973>': ['Bouchon'], '<http://www.wikidata.org/entity/Q4348225>': ['tea culture'], '<http://www.wikidata.org/entity/Q432535>': ['Ancient Egyptian cuisine'], '<http://www.wikidata.org/entity/Q638022>': ['vegetarian cuisine'], '<http://www.wikidata.org/entity/Q765174>': ['Levantine cuisine'], '<http://www.wikidata.org/entity/Q192935>': ['seafood'], '<http://www.wikidata.org/entity/Q2006309>': ['Aztec cuisine'], '<http://www.wikidata.org/entity/Q85430164>': ['Creole cuisine'], '<http://www.wikidata.org/entity/Q3699146>': ['Roman cuisine'], '<http://www.wikidata.org/entity/Q16268311>': ['Q16268311'], '<http://www.wikidata.org/entity/Q16481853>': ['Q16481853'], '<http://www.wikidata.org/entity/Q5408968>': ['Makki di roti'], '<http://www.wikidata.org/entity/Q16143746>': ['Western cuisine'], '<http://www.wikidata.org/entity/Q7010123>': ['New Mexican cuisine'], '<http://www.wikidata.org/entity/Q18915464>': ['Q18915464'], '<http://www.wikidata.org/entity/Q16984298>': ['Saint Louis cuisine'], '<http://www.wikidata.org/entity/Q17002293>': ['Christmas Island cuisine'], '<http://www.wikidata.org/entity/Q20669090>': ['vegan cuisine'], '<http://www.wikidata.org/entity/Q20892186>': ['Nordic cuisine'], '<http://www.wikidata.org/entity/Q3595124>': ['Anglo-Indian cuisine'], '<http://www.wikidata.org/entity/Q7005323>': ['New American cuisine'], '<http://www.wikidata.org/entity/Q7401021>': ['Saint Barthélemy cuisine'], '<http://www.wikidata.org/entity/Q17176918>': ['Qiang cuisine'], '<http://www.wikidata.org/entity/Q8011654>': ['Sakana'], '<http://www.wikidata.org/entity/Q29578381>': ['Q29578381'], '<http://www.wikidata.org/entity/Q29639731>': ['Q29639731'], '<http://www.wikidata.org/entity/Q177378>': ['tofu'], '<http://www.wikidata.org/entity/Q284288>': ['Jewish cuisine'], '<http://www.wikidata.org/entity/Q101252181>': ['Samoan cuisine'], '<http://www.wikidata.org/entity/Q27477249>': ['Chinese cuisine'], '<http://www.wikidata.org/entity/Q18164994>': ['Hittite cuisine'], '<http://www.wikidata.org/entity/Q601763>': ['fusion cuisine'], '<http://www.wikidata.org/entity/Q640769>': ['jiaozi'], '<http://www.wikidata.org/entity/Q709287>': ['Hakka cuisine'], '<http://www.wikidata.org/entity/Q859283>': ['Yunnan cuisine'], '<http://www.wikidata.org/entity/Q934309>': ['Mediterranean cuisine'], '<http://www.wikidata.org/entity/Q19880298>': ['Cuisine of the Mid-Atlantic United States'], '<http://www.wikidata.org/entity/Q1983633>': ['Curaçao cuisine'], '<http://www.wikidata.org/entity/Q29572602>': ['Cuisine of the Pitcairn Islands and Norfolk Island'], '<http://www.wikidata.org/entity/Q3345199>': ['New Nordic Cuisine'], '<http://www.wikidata.org/entity/Q3699131>': ['Italian-American cuisine'], '<http://www.wikidata.org/entity/Q3763843>': ['Giardiniera'], '<http://www.wikidata.org/entity/Q5097183>': ['Chifa'], '<http://www.wikidata.org/entity/Q16256231>': ['Korean temple cuisine'], '<http://www.wikidata.org/entity/Q17020498>': ['Hawaii regional cuisine'], '<http://www.wikidata.org/entity/Q555997>': ['soul food'], '<http://www.wikidata.org/entity/Q733573>': ['molecular gastronomy'], '<http://www.wikidata.org/entity/Q10286142>': ['fucha ryōri'], '<http://www.wikidata.org/entity/Q1859351>': ['Sicilian cuisine'], '<http://www.wikidata.org/entity/Q3595460>': ['cuisine of Meghalaya'], '<http://www.wikidata.org/entity/Q7091754>': ['Once-a-month cooking'], '<http://www.wikidata.org/entity/Q1261477>': ['English cuisine'], '<http: ...

# %%
# J'enregistre les données dans le fichier cusine_URL_Nom_WIKI.json
a = json.dumps(dic_label_nom, ensure_ascii=False)
f = open("cusine_URL_Nom_WIKI.json","w", encoding="UTF-8")
f.write(a)
f.close()

# %%
dic_nom_label = {}
for i in label_nom:
    #print(i["item"])
    #print(i["itemLabel"])
    dic_nom_label[i["itemLabel"]] = "<"+i["item"]+">"# j'ajoute les chevrons pour les URL de wikipedia

# %%
print(dic_nom_label)
# Out:
# {'Q589264': '<http://www.wikidata.org/entity/Q589264>', 'Cajun cuisine': '<http://www.wikidata.org/entity/Q969579>', 'Dutch-Antillian cuisine': '<http://www.wikidata.org/entity/Q2053168>', 'Indonesian-Dutch cuisine': '<http://www.wikidata.org/entity/Q2228549>', 'Q3006899': '<http://www.wikidata.org/entity/Q3006899>', 'Q3699117': '<http://www.wikidata.org/entity/Q3699117>', 'Q3699150': '<http://www.wikidata.org/entity/Q3699150>', 'Chettinad cuisine': '<http://www.wikidata.org/entity/Q3525354>', 'Bouchon': '<http://www.wikidata.org/entity/Q3006973>', 'tea culture': '<http://www.wikidata.org/entity/Q4348225>', 'Ancient Egyptian cuisine': '<http://www.wikidata.org/entity/Q432535>', 'vegetarian cuisine': '<http://www.wikidata.org/entity/Q638022>', 'Levantine cuisine': '<http://www.wikidata.org/entity/Q765174>', 'seafood': '<http://www.wikidata.org/entity/Q192935>', 'Aztec cuisine': '<http://www.wikidata.org/entity/Q2006309>', 'Creole cuisine': '<http://www.wikidata.org/entity/Q85430164>', 'Roman cuisine': '<http://www.wikidata.org/entity/Q3699146>', 'Q16268311': '<http://www.wikidata.org/entity/Q16268311>', 'Q16481853': '<http://www.wikidata.org/entity/Q16481853>', 'Makki di roti': '<http://www.wikidata.org/entity/Q5408968>', 'Western cuisine': '<http://www.wikidata.org/entity/Q16143746>', 'New Mexican cuisine': '<http://www.wikidata.org/entity/Q7010123>', 'Q18915464': '<http://www.wikidata.org/entity/Q18915464>', 'Saint Louis cuisine': '<http://www.wikidata.org/entity/Q16984298>', 'Christmas Island cuisine': '<http://www.wikidata.org/entity/Q17002293>', 'vegan cuisine': '<http://www.wikidata.org/entity/Q20669090>', 'Nordic cuisine': '<http://www.wikidata.org/entity/Q20892186>', 'Anglo-Indian cuisine': '<http://www.wikidata.org/entity/Q3595124>', 'New American cuisine': '<http://www.wikidata.org/entity/Q7005323>', 'Saint Barthélemy cuisine': '<http://www.wikidata.org/entity/Q7401021>', 'Qiang cuisine': '<http://www.wikidata.org/entity/Q56301925>', 'Sakana': '<http://www.wikidata.org/entity/Q8011654>', 'Q29578381': '<http://www.wikidata.org/entity/Q29578381>', 'Q29639731': '<http://www.wikidata.org/entity/Q29639731>', 'tofu': '<http://www.wikidata.org/entity/Q177378>', 'Jewish cuisine': '<http://www.wikidata.org/entity/Q284288>', 'Samoan cuisine': '<http://www.wikidata.org/entity/Q101252181>', 'Chinese cuisine': '<http://www.wikidata.org/entity/Q27477249>', 'Hittite cuisine': '<http://www.wikidata.org/entity/Q18164994>', 'fusion cuisine': '<http://www.wikidata.org/entity/Q601763>', 'jiaozi': '<http://www.wikidata.org/entity/Q640769>', 'Hakka cuisine': '<http://www.wikidata.org/entity/Q709287>', 'Yunnan cuisine': '<http://www.wikidata.org/entity/Q859283>', 'Mediterranean cuisine': '<http://www.wikidata.org/entity/Q934309>', 'Cuisine of the Mid-Atlantic United States': '<http://www.wikidata.org/entity/Q19880298>', 'Curaçao cuisine': '<http://www.wikidata.org/entity/Q1983633>', 'Cuisine of the Pitcairn Islands and Norfolk Island': '<http://www.wikidata.org/entity/Q29572602>', 'New Nordic Cuisine': '<http://www.wikidata.org/entity/Q3345199>', 'Italian-American cuisine': '<http://www.wikidata.org/entity/Q3699131>', 'Giardiniera': '<http://www.wikidata.org/entity/Q3763843>', 'Chifa': '<http://www.wikidata.org/entity/Q5097183>', 'Korean temple cuisine': '<http://www.wikidata.org/entity/Q16256231>', 'Hawaii regional cuisine': '<http://www.wikidata.org/entity/Q17020498>', 'soul food': '<http://www.wikidata.org/entity/Q555997>', 'molecular gastronomy': '<http://www.wikidata.org/entity/Q733573>', 'fucha ryōri': '<http://www.wikidata.org/entity/Q10286142>', 'Sicilian cuisine': '<http://www.wikidata.org/entity/Q1859351>', 'cuisine of Meghalaya': '<http://www.wikidata.org/entity/Q3595460>', 'Once-a-month cooking': '<http://www.wikidata.org/entity/Q7091754>', 'English cuisine': '<http://www.wikidata.org/entity/Q1261477>', 'Scottish cuisine': '<http://www.wikidata.org/entity/Q1897293>', 'Gheimeh': '<http://www.wikidata.org/entity/Q5556168>', 'Bulun ...

# %%
# j'enregistre les données dans le fichier cusine_Nom_URL_WIKI.json
a = json.dumps(dic_nom_label, ensure_ascii=False)
f = open("cusine_Nom_URL_WIKI.json","w", encoding="UTF-8")
f.write(a)
f.close()

# %%
import csv

# %%
# créer un fichier csv dans lequel les URL des entités ont tous les chevrons 
# cela me permet de récupérer facilement les URL correspondant dans DBpedia et les plongements dans l'étape suivante. 
with open("cusine_avec_chevron.csv","w", encoding ="UTF-8") as f:   
    for i in label_nom:
        f.write("<"+i["item"]+">"+"\n")
