# %%
import gensim
model = gensim.models.Word2Vec.load("~/Desktop/Mémoire_M1/Data/emb/emb_dbpedia_rdf2vec/emb_wikidata_rdf2vec/wikid2Vec_sg_200_5_5_15_4_500")

# %%
print(model.wv["http://www.wikidata.org/entity/Q10325851"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hg/7br5zrvs767779d6zygcqyf40000gn/T/ipykernel_19969/1718370942.py in <module>
# ----> 1 print(model.wv["http://www.wikidata.org/entity/Q10325851"])
#
# NameError: name 'model' is not defined

# %%
import json
chemin = "../film/1500_film_URL_Nom_WIKI.json"

# %%
list_film = []
labels = open(chemin, "r", encoding="UTF-8")
label_nom = json.load(labels )
for c,v in label_nom.items():
    list_film.append(c)

# %%
print(list_film)
# Out:
# ['<http://www.wikidata.org/entity/Q151320>', '<http://www.wikidata.org/entity/Q125494>', '<http://www.wikidata.org/entity/Q128646>', '<http://www.wikidata.org/entity/Q129051>', '<http://www.wikidata.org/entity/Q134075>', '<http://www.wikidata.org/entity/Q151358>', '<http://www.wikidata.org/entity/Q144380>', '<http://www.wikidata.org/entity/Q150804>', '<http://www.wikidata.org/entity/Q151751>', '<http://www.wikidata.org/entity/Q152232>', '<http://www.wikidata.org/entity/Q156516>', '<http://www.wikidata.org/entity/Q153484>', '<http://www.wikidata.org/entity/Q126652>', '<http://www.wikidata.org/entity/Q128982>', '<http://www.wikidata.org/entity/Q152456>', '<http://www.wikidata.org/entity/Q136605>', '<http://www.wikidata.org/entity/Q151643>', '<http://www.wikidata.org/entity/Q130297>', '<http://www.wikidata.org/entity/Q141557>', '<http://www.wikidata.org/entity/Q146673>', '<http://www.wikidata.org/entity/Q150949>', '<http://www.wikidata.org/entity/Q151695>', '<http://www.wikidata.org/ent
# ...

# %%
for i in list_film:
    print(model.wv[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hg/7br5zrvs767779d6zygcqyf40000gn/T/ipykernel_19969/803861297.py in <module>
#       1 for i in list_film:
# ----> 2     print(model.wv[i])
#
# NameError: name 'model' is not defined
